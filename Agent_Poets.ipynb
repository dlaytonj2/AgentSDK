# %%
import time

from datetime import datetime

def get_time():
    # Get the current time
    current_time = datetime.now()

    # Format the time in hh:mm:ss format
    formatted_time = current_time.strftime("%H:%M:%S")

    # Print the formatted time
    return formatted_time

# %%
import os
os.environ["OPENAI_API_KEY"] = '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'

from agents import Agent, Runner

# %%
useModel = "gpt-4o"

Poet_Agent = Agent(
    name="James",
    instructions="You are an expert at writing poetry",
    model=useModel,
)

Analyst_Agent = Agent(
    name="Owen",
    instructions="You are expert in analyzing poetry.You provide positive and constructive feedback",
    model=useModel,
)

"""We are going to write a poem, there will be two assistants; a Poet and an Analyst.
The Poet will write poem and the Analyst will provide constructive feedback which the Poet
will use when rewriting the poem"""


result = await Runner.run(
    starting_agent= Poet_Agent,
    input= """"Identify yourself as the Poet. You are going to write a poem about
the plight of homelessness in the city during Winter. Use a free verse style.  There should be no internal or external rhyming.
Think about this step by step. First describe your approach to the poem, then write the poem."""
)
print('\n',result.final_output) 

Draft_Poem = result.final_output


result = await Runner.run(
    starting_agent= Analyst_Agent,
    input=f"""Identify yourself as the Poet Analyst and then provide constructive feedback to what 
the Poet assistant has written. Think about this step by step, but do not rewrite the poem.
Here is the first draft of the poem...{Draft_Poem}..."""
)
print('\n',result.final_output) 
Analysis = result.final_output

result = await Runner.run(
    starting_agent= Poet_Agent,
    input=f"""Identify yourself as the Poet again  and then think about this step by step. 
First, describe how you will use the feedback from the Analyst to improve the poem, then rewrite the poem using that feedback. 
Here is  the first draft of the poem ...{Draft_Poem}. Here is the feedback from the analyst ...{Analysis}"""
)
print('\n',result.final_output) 



print("\n All done. Carry on ")
# Out:
#  **Approach:**
#
# 1. **Theme and Tone:** I will focus on the stark contrast between the warmth of the city’s heart and the cold reality faced by those without shelter. The tone will be somber and reflective, highlighting the poignant struggles of homelessness during winter.
#
# 2. **Imagery and Language:** I will use vivid imagery to paint a picture of the harsh winter environment juxtaposed against the bustling life of the city. The language will be descriptive, aiming to evoke empathy and awareness.
#
# 3. **Structure:** As it's free verse, I'll allow the imagery and narrative to guide the structure, breaking lines strategically to emphasize key points and emotions.
#
# **Poem:**
#
# ---
#
# Beneath the flickering streetlights,
# where shadows shiver in the biting wind,
# life unfolds in cardboard corners.
# Snow dusts the city,
# a delicate cruelty clinging to forgotten scarves
# and crumpled dreams.
#
# In the cacophony of hurried footsteps
# and the warmth of café laughter,
# ...
