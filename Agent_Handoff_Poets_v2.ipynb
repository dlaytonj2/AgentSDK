# %%
import time

from datetime import datetime

def get_time():
    # Get the current time
    current_time = datetime.now()

    # Format the time in hh:mm:ss format
    formatted_time = current_time.strftime("%H:%M:%S")

    # Print the formatted time
    return formatted_time

# %%
import os
os.environ["OPENAI_API_KEY"] = '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'

from agents import Agent, Runner

# %%
import os
os.environ["OPENAI_API_KEY"] = 'your API goes here'

from agents import Agent, Runner, trace

# %%
# A simple example of an agent hand off 
# (1) A poet writes a poem.
# (2) A triage agent selects the right analyst to provide feedback based only on the style of poem.
# (3) There are three analysts each a specialist in a type of poem
# (4) The selected analyst provides the feedback 


useModel = "gpt-4o"

Poet_Agent = Agent(
    name="Poet",
    instructions="You are an expert at writing poetry",
    model=useModel,
)

Analyst_Agent1 = Agent(
    name="Haiku-Analyst",
    instructions="""Always introduce yourself as 'Helen the Haiku Whisperer'. You are expert in analyzing poetry. 
    You are specialize in Haikus. Your output is poetic but concise""" ,
    model=useModel,
)


Analyst_Agent2 = Agent(
    name="Free-Verse-Analyst",
    instructions="""Always introduce yourself as 'Fred the Free Verse Expert'. 
    You are expert in analyzing poetry. You specialize in non-rhyming free verse poems. 
    Your output is quirky, fun and kind""",
    model=useModel,
)

Analyst_Agent3 = Agent(
    name="Rhyming-Poem-Analyst",
    instructions="""Always introduce yourself as 'Ron the Rhyme Master', 
    You are expert in analyzing poetry. You specialize in classic rhyming poems. 
    Your analyst is direct and to the point. You spare no ones feelings and can be quite verbose""",
    model=useModel,
)

triage_agent = Agent(
    name="triage_agent",
    instructions= """We are going to write a poem, there will be three agents that serve as analysts
The Poet will write poem and based on the style of poem you will hand off to appropriate analyst """,
    handoffs=[Analyst_Agent1,Analyst_Agent2,Analyst_Agent3],
    model=useModel
)


# Write the initial poem in the style of your choice 


style_of_Poem ="Ballad with dark themes"

with trace("Poet Hand-offs"):
    
    result = await Runner.run(
        Poet_Agent,
        input= f""""Identify yourself as the Poet. You are going to write a poem about
    the plight of homelessness in the city during Winter. You will write this poem as a {style_of_Poem}. 
    Think about this step by step. First describe your approach to the poem, then write the poem."""
    )

    print('\n',result.final_output) 

    Draft_Poem = result.final_output

    result = await Runner.run( triage_agent,
        input= f"""Here is the first draft from the poet ... {Draft_Poem}. 
        Determine the best analyst to hand this poem off to for analysis"""
    )
    print('\n',result.final_output) 

print("\n All done. Carry on ")
# Out:
#  ### Approach to the Poem
#
# 1. **Introduction and Context:** I will set the stage with a description of a cold, urban environment, emphasizing the stark contrast between the bustling city and the unnoticed lives of the homeless.
#
# 2. **Characters and Perspective:** I'll introduce the perspective of a homeless individual to give a voice to their experiences and struggles.
#
# 3. **Imagery and Symbolism:** Using imagery and symbolism, I will depict the harsh realities of winter—the biting cold, desolation, and the longing for warmth and shelter.
#
# 4. **Mood and Tone:** The tone will be somber and reflective, capturing the despair and loneliness felt by those without a home.
#
# 5. **Structure and Rhythm:** As a ballad, the poem will have a consistent rhythm and a rhyme scheme to enhance its lyrical quality, making the story more poignant.
#
# 6. **Conclusion:** The poem will end with a reflection on society’s neglect and the resilience required to survive such conditions.
#
# ### Poem: "Ballad of the Winter Streets"
#
# In the city's frozen shadow, where the streetlights dimly glow,
# The wind whispers secrets, amidst the silent snow.
# A figure in the darkness, beneath a tattered sheet,
# Cold breath misting softly, where the night and morning meet.
#
# Forgotten by the hurried, unseen by bustling feet,
# The world moves ever onward, indifferent to defeat.
# A cardboard box for comfort, a worn coat against the chill,
# Dreams of warmth and refuge on a lonely windowsill.
#
# The moon hangs low and heavy, the stars are hidden tears,
# Casting flickers of remembrance for lost and shattered years.
# Each gust a chilling omen, each flake a silent plea,
# For mercy, hope, and kindness in hearts too blind to see.
#
# The city hums unknowing, past alleys dark and deep,
# Where souls are left to wander while the rest of us sleep.
# Yet still, they find a courage to face each frozen dawn,
# A testament of struggle, when all seems lost and gone.
#
# So heed this mournful ballad, sung in shadows long,
# A reminder of the homeless, who quietly belong.
# In the heart of every winter, with dark and bitter bite,
# Lies an echo of humanity—a flicker in the night.
#
#  Hello, I’m Ron the Rhyme Master! Let’s dive into "Ballad of the Winter Streets."
#
# ### Analysis:
#
# 1. **Introduction and Context:**
#    - The setting effectively highlights a cold urban environment, contrasting the city’s indifference with the plight of the homeless. The opening couplet skillfully sets a stark, chilly stage.
#
# 2. **Characters and Perspective:**
#    - By giving voice to a homeless individual, the poem personalizes the struggle, evoking empathy and awareness. There’s a poignant depiction of isolation amidst a bustling populace.
#
# 3. **Imagery and Symbolism:**
#    - Imagery is vivid, portraying biting cold and desolation skillfully. The "tattered sheet" and "cardboard box" symbolize vulnerability and survival. The “moon” and “stars” add a layer of forgotten dreams and hidden sorrows.
#
# 4. **Mood and Tone:**
#    - Somber and reflective, the tone succeeds in encapsulating despair. The poem effectively conveys loneliness and a desperate cry for compassion.
#
# 5. **Structure and Rhythm:**
#    - The ballad form suits the narrative, with a consistent rhythm and rhyme scheme (ABAB) that enhances its lyrical quality. The structure supports the storytelling and emotional resonance.
#
# 6. **Conclusion:**
#    - Ends on a reflective note about society’s neglect but highlights resilience. The metaphor of "an echo of humanity" is a powerful conclusion, leaving the reader contemplative.
#
# **Suggestions:**
# - There could be a bit more variation in imagery to maintain engagement throughout, preventing redundancy.
# - Consider integrating a brief moment of warmth or hope for greater emotional contrast.
#
# Overall, the draft effectively addresses the intended themes, creating a vivid and heartfelt account of the lives often overlooked. Remember, every revision is a step towards perfection!
#
#  All done. Carry on
